# %%
from scipy import stats

g1 = [120,135,150,145,160,155,140]
g2 = [130,142,138,145,150,148,152]
g3 = [160,170,165,180,175,172,168]

f_stat, p_value = stats.f_oneway(g1, g2, g3)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 17.302831142568248
# p-value: 6.429247027937587e-05
